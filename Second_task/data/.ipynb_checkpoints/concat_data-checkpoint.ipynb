# %%
import pandas as pd

# %%
df_201912 = pd.read_csv('subway_on_off/CARD_SUBWAY_MONTH_201912.csv', encoding='cp949')
df_202001 = pd.read_csv('subway_on_off/CARD_SUBWAY_MONTH_202001.csv', encoding='cp949', index_col=False)

df_address = pd.read_excel('subway_address/4647,4661번 서울교통공사 역별 주소 현황 및 전화번호.xlsx', header=1, index_col=0)

# %%
df_on_off = pd.concat([df_201912, df_202001]).reset_index(drop=True)
all_df = pd.merge(df_on_off, df_address).rename(columns={'Unnamed: 6' : '전화번호'})
all_df['상세주소_역이름'] = all_df['상세주소'].map(lambda x : x.split(' ')[-1])
all_df['상세주소'] = all_df['상세주소'].map(lambda x : ' '.join(x.split(' ')[:-1]))

# %%
all_df.shape
# Out:
# (23979, 13)

# %%
all_df.head()
# Out:
#        사용일자  노선명  역ID  역명   승차총승객수   하차총승객수      등록일자  호선    구     동  \
# 0  20191201  1호선  152  종각  19093.0  17141.0  20191204   1  종로구  종로1가
# 1  20191202  1호선  152  종각  48153.0  46770.0  20191205   1  종로구  종로1가
# 2  20191203  1호선  152  종각  49696.0  47715.0  20191206   1  종로구  종로1가
# 3  20191204  1호선  152  종각  49877.0  48664.0  20191207   1  종로구  종로1가
# 4  20191205  1호선  152  종각  51426.0  49816.0  20191208   1  종로구  종로1가
#
#                 상세주소       전화번호 상세주소_역이름
# 0  서울특별시 종로구 종로1가 54  6110-1311  종각지하철역사
# 1  서울특별시 종로구 종로1가 54  6110-1311  종각지하철역사
# 2  서울특별시 종로구 종로1가 54  6110-1311  종각지하철역사
# 3  서울특별시 종로구 종로1가 54  6110-1311  종각지하철역사
# 4  서울특별시 종로구 종로1가 54  6110-1311  종각지하철역사

# %%
all_df.tail()
# Out:
#            사용일자  노선명   역ID  역명  승차총승객수  하차총승객수      등록일자  호선    구        동  \
# 23974  20200127  8호선  2826  수진  3207.0  3125.0  20200130   8  성남시  수정구 수진동
# 23975  20200128  8호선  2826  수진  5593.0  5180.0  20200131   8  성남시  수정구 수진동
# 23976  20200129  8호선  2826  수진  6425.0  5988.0  20200201   8  성남시  수정구 수진동
# 23977  20200130  8호선  2826  수진  5825.0  5354.0  20200202   8  성남시  수정구 수진동
# 23978  20200131  8호선  2826  수진  6199.0  5660.0  20200203   8  성남시  수정구 수진동
#
#                          상세주소       전화번호 상세주소_역이름
# 23974  경기도 성남시 수정구 수진동 2205-1  6311-8250      수진역
# 23975  경기도 성남시 수정구 수진동 2205-1  6311-8250      수진역
# 23976  경기도 성남시 수정구 수진동 2205-1  6311-8250      수진역
# 23977  경기도 성남시 수정구 수진동 2205-1  6311-8250      수진역
# 23978  경기도 성남시 수정구 수진동 2205-1  6311-8250      수진역

# %%
all_df.to_csv('all_df.csv', index=False)
